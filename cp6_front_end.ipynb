# %% [markdown]
# # Prophet Facebook
# * https://facebook.github.io/prophet/docs/quick_start.html

# %% [markdown]
# #gabriel Silva rm:552397
# #Lucas Caspirro Gitti Alcaraz rm:551090
# #Erick Camargo Eleutério rm:99771
# #Henzzo Fonseca rm:97917

# %% [markdown]
# # Install

# %%
pip install prophet
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.2.4)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays<1,>=0.25 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.59)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.66.5)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (6.4.5)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays<1,>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)

# %%
from prophet import Prophet

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import plotly.express as px
import itertools

#TimeSeries
from prophet import Prophet #case sensitive, needs to be Prophet with capital "P"
from prophet.plot import plot_plotly, plot_components_plotly
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

pd.set_option('display.max_rows',100)
pd.set_option('display.max_columns',200)
pd.set_option('display.width',1000)

# %% [markdown]
# # Load Datasets

# %%
# Vamos importar a base para o nosso notebook e dar uma primeira "olhada" nos dados:
ts_raw = pd.read_csv('https://raw.githubusercontent.com/abnr/ml-data/main/stocks_ABBV.csv', index_col=[0])
ts_raw
# Out:
#             Date       Open       High        Low      Close  Adj Close     Volume
# 0     2018-11-23  85.599998  86.550003  84.900002  85.629997  78.807220    1612800
# 1     2013-12-24  52.779999  52.790001  52.279999  52.360001  40.406071    1747000
# 2     2019-12-24  90.400002  90.400002  89.430000  89.849998  88.652267    1798800
# 3     2017-12-28  98.190002  98.389999  97.519997  97.790001  86.620544    1870400
# 4     2017-12-27  97.730003  98.230003  97.440002  98.089996  86.886284    1927300
# ...          ...        ...        ...        ...        ...        ...        ...
# 1820  2015-10-22  53.880001  54.439999  45.450001  48.270000  39.716072   46517700
# 1821  2015-03-05  57.209999  59.480000  56.650002  56.860001  45.636005   47051800
# 1822  2014-10-16  55.799999  55.900002  52.840000  52.900002  42.141338   61236700
# 1823  2019-06-25  70.470001  70.669998  65.059998  65.699997  62.018341   90131800
# 1824  2014-10-15  52.330002  55.720001  52.060001  54.630001  43.519489  122740200
#
# [1825 rows x 7 columns]

# %% [markdown]
# # Prophet
# * https://facebook.github.io/prophet/docs/

# %%
# Vamos separar agora apenas os dados de fechamento, e estuda-la como uma série temporal
ts = ts_raw[['Date', 'Close']].copy()

# Renomeando as features para o padrão exigido pelo prophet
ts.rename(columns = {'Date':'ds',
                     'Close':'y'}, inplace = True)

#transformando ds para datetime
ts['ds'] = pd.to_datetime(ts['ds'])
ts = ts.sort_values('ds')
display(ts.head())
display(ts.tail())
# Out:
#              ds          y
# 1676 2013-01-02  35.119999
# 1743 2013-01-03  34.830002
# 1792 2013-01-04  34.389999
# 1759 2013-01-07  34.459999
# 1757 2013-01-08  33.709999
#              ds          y
# 1730 2020-03-26  73.830002
# 1613 2020-03-27  72.669998
# 1508 2020-03-30  75.239998
# 1785 2020-03-31  76.190002
# 1648 2020-04-01  73.419998

# %%
df_plot = ts.copy()
df_plot.set_index('ds', inplace = True)
df_plot.plot(figsize=(20, 6))

plt.title('Stocks - ABBV valores fechamento')
plt.ylabel('preço (US$)')
plt.xlabel('time');

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Utilizando o df completo para o fit do modelo

# %%
display(ts.shape)
display('Tail do dataframe original: ',ts.tail() )
# Out:
# (1825, 2)
# 'Tail do dataframe original: '
#              ds          y
# 1730 2020-03-26  73.830002
# 1613 2020-03-27  72.669998
# 1508 2020-03-30  75.239998
# 1785 2020-03-31  76.190002
# 1648 2020-04-01  73.419998

# %% [markdown]
# ## m0

# %%
#instanciando o modelo
m0 = Prophet()
m0.fit(ts)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/75esk6nu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/so8kgk3m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87197', 'data', 'file=/tmp/tmp5d92cl46/75esk6nu.json', 'init=/tmp/tmp5d92cl46/so8kgk3m.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model7t06ev67/prophet_model-20241028231236.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:12:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:12:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
#criando os timestamps futuros para receber as previsões
future = m0.make_future_dataframe(periods=365, include_history=False)
print('Forecast excluindo histórico de treinamento: ', future.shape)
display('Head dos primeiros 5 timestamps de 365 no total: ', future.head(5))

future = m0.make_future_dataframe(periods=365, include_history=True)
print('\nForecast incluindo histórico: ', future.shape)
display('Tail dos últimos 5 timestamps de 365 no total: ', future.tail(5))
# Out:
# Forecast excluindo histórico de treinamento:  (365, 1)
# 'Head dos primeiros 5 timestamps de 365 no total: '
#           ds
# 0 2020-04-02
# 1 2020-04-03
# 2 2020-04-04
# 3 2020-04-05
# 4 2020-04-06
# Forecast incluindo histórico:  (2190, 1)
# 'Tail dos últimos 5 timestamps de 365 no total: '
#              ds
# 2185 2021-03-28
# 2186 2021-03-29
# 2187 2021-03-30
# 2188 2021-03-31
# 2189 2021-04-01

# %%
#gerando as previsões para os timestamps criados na célula anterior
forecast = m0.predict(future)
display('Tail das últimas 5 previsões: ', forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 'Tail das últimas 5 previsões: '
#              ds       yhat  yhat_lower  yhat_upper
# 2185 2021-03-28  67.995491   50.926492   86.259825
# 2186 2021-03-29  68.911172   52.082755   86.158517
# 2187 2021-03-30  68.702257   52.036944   86.522208
# 2188 2021-03-31  68.639212   51.030839   86.721665
# 2189 2021-04-01  68.610415   50.799820   87.163627

# %%
fig1 = m0.plot(forecast)

# %%
#componentes
fig2 = m0.plot_components( forecast,
                          uncertainty = True,
                          plot_cap = True,
                          weekly_start = 1,
                          yearly_start = 1,
                          )
'''
weekly_start Integer specifying the start day of the weekly seasonality plot. 0 (default) starts
the week on Sunday. 1 shifts by 1 day to Monday, and so on.

yearly_start Integer specifying the start day of the yearly seasonality plot. 0 (default) starts
the year on Jan 1. 1 shifts by 1 day to Jan 2, and so on
'''
# Out:
# '\nweekly_start Integer specifying the start day of the weekly seasonality plot. 0 (default) starts\nthe week on Sunday. 1 shifts by 1 day to Monday, and so on.\n\nyearly_start Integer specifying the start day of the yearly seasonality plot. 0 (default) starts\nthe year on Jan 1. 1 shifts by 1 day to Jan 2, and so on\n'

# %%
#componentes com plotly
from prophet.plot import plot_plotly, plot_components_plotly

fig1 = plot_plotly(m0, forecast)
fig1.show()

fig2 = plot_components_plotly(m0, forecast)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id
O parâmetro changepoint_prior_scale é um hiperparâmetro importante no contexto do Prophet, que é uma ferramenta de previsão de séries temporais
desenvolvida pelo Facebook.
Esse parâmetro controla a flexibilidade do modelo na detecção de mudanças abruptas nos dados de séries temporais.
Em essência, ele controla a penalização aplicada às mudanças na tendência da série temporal.

Aqui estão os detalhes de como o parâmetro changepoint_prior_scale afeta o modelo Prophet:

Valores Baixos: Quando você define um valor baixo para changepoint_prior_scale, o modelo será mais conservador na detecção de mudanças.
Isso significa que ele considerará menos pontos de dados como pontos de virada significativos na série temporal.
O resultado pode ser um modelo que se ajusta melhor a séries temporais com mudanças suaves e graduais na tendência.

Valores Elevados: Por outro lado, se você definir um valor alto para changepoint_prior_scale, o modelo será mais flexível na detecção de mudanças.
Ele considerará mais pontos de dados como potenciais pontos de virada, tornando-se mais sensível a flutuações nos dados.
Isso pode levar a um modelo que se ajusta bem a séries temporais com mudanças abruptas e irregulares na tendência.

A escolha apropriada do valor para changepoint_prior_scale depende da natureza dos dados da sua série temporal.
Se você souber que a série temporal possui mudanças bruscas e imprevisíveis, pode ser apropriado usar um valor baixo para tornar o modelo mais conservador.
Por outro lado, se as mudanças na série temporal forem frequentes e irregulares, um valor mais alto pode ser mais adequado.

Em geral, é uma boa prática ajustar o changepoint_prior_scale durante o processo de ajuste do modelo Prophet para encontrar o valor que melhor
se adapta aos seus dados específicos, usando validação cruzada ou outros métodos de otimização.
Experimentar diferentes valores e avaliar o desempenho do modelo em dados de validação ou teste pode ajudar a determinar o valor ideal
para esse parâmetro.
'''
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/0rfw6ib4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/wfagnw9a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13276', 'data', 'file=/tmp/tmp5d92cl46/0rfw6ib4.json', 'init=/tmp/tmp5d92cl46/wfagnw9a.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelicmb9rvy/prophet_model-20241028231243.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:12:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:12:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# '\nO parâmetro changepoint_prior_scale é um hiperparâmetro importante no contexto do Prophet, que é uma ferramenta de previsão de séries temporais\ndesenvolvida pelo Facebook.\nEsse parâmetro controla a flexibilidade do modelo na detecção de mudanças abruptas nos dados de séries temporais.\nEm essência, ele controla a penalização aplicada às mudanças na tendência da série temporal.\n\nAqui estão os detalhes de como o parâmetro changepoint_prior_scale afeta o modelo Prophet:\n\nValores Baixos: Quando você define um valor baixo para changepoint_prior_scale, o modelo será mais conservador na detecção de mudanças.\nIsso significa que ele considerará menos pontos de dados como pontos de virada significativos na série temporal.\nO resultado pode ser um modelo que se ajusta melhor a séries temporais com mudanças suaves e graduais na tendência.\n\nValores Elevados: Por outro lado, se você definir um valor alto para changepoint_prior_scale, o modelo será mais flexível na detecção de mudanças.\nEle considerará mais pontos de dados como potenciais pontos de virada, tornando-se mais sensível a flutuações nos dados.\nIsso pode levar a um modelo que se ajusta bem a séries temporais com mudanças abruptas e irregulares na tendência.\n\nA escolha apropriada do valor para changepoint_prior_scale depende da natureza dos dados da sua série temporal.\nSe você souber que a série temporal possui mudanças bruscas e imprevisíveis, pode ser apropriado usar um valor baixo para tornar o modelo mais conservador.\nPor outro lado, se as mudanças na série temporal forem frequentes e irregulares, um valor mais alto pode ser mais adequado.\n\nEm geral, é uma boa prática ajustar o changepoint_prior_scale durante o processo de ajuste do modelo Prophet para encontrar o valor que melhor\nse adapta aos seus dados específicos, usando validação cruzada ou outros métodos de otimização.\nExperimentar diferentes valores e avaliar o desempenho do modelo em dados de validação ou teste pode ajudar a determinar o valor ideal\npara esse parâmetro.\n'

# %% [markdown]
# ## m2

# %%
# changepoint_prior_scale = 0.001
# decreasing it will make the trend less flexible

m2 = Prophet(changepoint_prior_scale=0.99)
forecast = m2.fit(ts).predict(future)

fig = m2.plot(forecast)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/jpg4hycr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/tb67d5xh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78009', 'data', 'file=/tmp/tmp5d92cl46/jpg4hycr.json', 'init=/tmp/tmp5d92cl46/tb67d5xh.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model3yzjeqt3/prophet_model-20241028231247.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:12:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:12:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# # Specifying the locations of the changepoints

# %% [markdown]
# ## m3

# %%
m3 = Prophet(changepoints=['2019-08'])
forecast = m3.fit(ts).predict(future)
fig = m3.plot(forecast)
plt.title('Changepoints = 2019-08')
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/o_ft753p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/03wpvry6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73012', 'data', 'file=/tmp/tmp5d92cl46/o_ft753p.json', 'init=/tmp/tmp5d92cl46/03wpvry6.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modeln4vt74_f/prophet_model-20241028231253.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:12:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:12:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Text(0.5, 1.0, 'Changepoints = 2019-08')

# %% [markdown]
# ## m4

# %%
m4 = Prophet(changepoints=['2018-01'])
forecast = m4.fit(ts).predict(future)
fig = m4.plot(forecast)
plt.title('Changepoints = 2018-01')
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/o__9qcwv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/da3eyvca.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17133', 'data', 'file=/tmp/tmp5d92cl46/o__9qcwv.json', 'init=/tmp/tmp5d92cl46/da3eyvca.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelbd0s8762/prophet_model-20241028231255.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:12:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:12:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Text(0.5, 1.0, 'Changepoints = 2018-01')

# %% [markdown]
# # Cross Validation

# %%
df_validacao = pd.DataFrame(columns = (['modelo', 'MSE', 'MSE_std']))

# %% [markdown]
# ## Prophet | Treino 1 ano | Horizon 22 (m0)

# %%
from prophet.diagnostics import cross_validation
df_cv_m0 = cross_validation(m0, period='365 days', horizon = '22 days')
display(df_cv_m0.shape)
df_cv_m0
# Out:
# INFO:prophet:Making 7 forecasts with cutoffs between 2014-03-12 00:00:00 and 2020-03-10 00:00:00
#   0%|          | 0/7 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/slh654gh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/1swdl7up.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42942', 'data', 'file=/tmp/tmp5d92cl46/slh654gh.json', 'init=/tmp/tmp5d92cl46/1swdl7up.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modeliracphvv/prophet_model-20241028231258.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:12:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:12:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/w8wbqbah.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/ax68pqcm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33179', 'data', 'file=/tmp/tmp5d92cl46/w8wbqbah.json', 'init=/tmp/tmp5d92cl46/ax68pqcm.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelqvg1ue9t/prophet_model-20241028231259.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:12:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:12:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/_tjmdowj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/noxbu_vm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89357', 'data', 'file=/tmp/tmp5d92cl46/_tjmdowj.json', 'init=/tmp/tmp5d92cl46/noxbu_vm.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelunzobsy9/prophet_model-20241028231300.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/d2kww7m9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/pix5uvaz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15483', 'data', 'file=/tmp/tmp5d92cl46/d2kww7m9.json', 'init=/tmp/tmp5d92cl46/pix5uvaz.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model_neekk8t/prophet_model-20241028231301.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/7xrmv5t6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/zp3_hzqe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17507', 'data', 'file=/tmp/tmp5d92cl46/7xrmv5t6.json', 'init=/tmp/tmp5d92cl46/zp3_hzqe.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelbbx9dmo4/prophet_model-20241028231303.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/dnueiuk5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/68mkn28m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92238', 'data', 'file=/tmp/tmp5d92cl46/dnueiuk5.json', 'init=/tmp/tmp5d92cl46/68mkn28m.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modeled4tnmm5/prophet_model-20241028231304.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/6jf0pm1s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/24ultynk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44551', 'data', 'file=/tmp/tmp5d92cl46/6jf0pm1s.json', 'init=/tmp/tmp5d92cl46/24ultynk.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelj974jvei/prophet_model-20241028231305.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# (107, 6)
#             ds       yhat  yhat_lower  yhat_upper          y     cutoff
# 0   2014-03-13  51.111586   50.071712   52.137169  51.320000 2014-03-12
# 1   2014-03-14  51.293289   50.236430   52.395477  51.209999 2014-03-12
# 2   2014-03-17  51.271245   50.256513   52.321027  51.980000 2014-03-12
# 3   2014-03-18  51.509704   50.455488   52.616350  53.099998 2014-03-12
# 4   2014-03-19  51.508075   50.424401   52.523386  53.110001 2014-03-12
# ..         ...        ...         ...         ...        ...        ...
# 102 2020-03-26  74.868270   68.638359   80.987172  73.830002 2020-03-10
# 103 2020-03-27  74.832903   68.240555   80.812472  72.669998 2020-03-10
# 104 2020-03-30  74.318082   67.912691   80.180542  75.239998 2020-03-10
# 105 2020-03-31  74.081745   68.184631   80.950227  76.190002 2020-03-10
# 106 2020-04-01  73.981247   68.044804   79.938535  73.419998 2020-03-10
#
# [107 rows x 6 columns]

# %%
from prophet.diagnostics import performance_metrics
df_p_m0 = performance_metrics(df_cv_m0)
print('MSE médio: ', df_p_m0.mse.mean())
print('MSE std: ', df_p_m0.mse.std())
print('MSE 22: ', df_p_m0.mse[20])
display(df_p_m0)

new_row = pd.DataFrame([{'modelo': 'Prophet_Treino_365_Horizon_22_m0',
                         'MSE': np.round(df_p_m0.mse.mean(), 2),
                         'MSE_std': np.round(df_p_m0.mse.std(), 2)}])

df_validacao = pd.concat([df_validacao, new_row], ignore_index=True)

df_validacao
# Out:
# MSE médio:  33.8458122230311
# MSE std:  26.902355033510055
# MSE 22:  56.29567454715758
#    horizon        mse      rmse       mae      mape     mdape     smape  coverage
# 0   2 days  21.400584  4.626077  3.720609  0.042521  0.052321  0.042875      0.40
# 1   3 days  24.807004  4.980663  4.376954  0.052742  0.054776  0.053758      0.30
# 2   4 days  19.160470  4.377267  3.893500  0.050400  0.053236  0.051599      0.40
# 3   5 days   6.897514  2.626312  2.228682  0.033068  0.027880  0.033772      0.60
# 4   6 days   5.735407  2.394871  2.085842  0.033518  0.032598  0.034166      0.50
# 5   7 days   7.380942  2.716789  2.552848  0.040289  0.036440  0.040728      0.40
# 6   8 days   8.618874  2.935792  2.631319  0.039480  0.036440  0.039434      0.60
# 7   9 days   9.120350  3.019992  2.522014  0.036482  0.033037  0.036137      0.70
# 8  10 days  13.139762  3.624881  2.972621  0.044074  0.041420  0.043761      0.50
# 9  11 days  35.437550  5.952945  4.464724  0.060793  0.049132  0.060085      0.40
# 10 12 days  55.079580  7.421562  5.291676  0.067357  0.050900  0.066082      0.40
# 11 13 days  42.819238  6.543641  4.493064  0.064029  0.050886  0.062325      0.40
# 12 14 days  27.587436  5.252374  3.827132  0.058785  0.032336  0.056955      0.44
# 13 15 days  47.705183  6.906894  4.587397  0.061769  0.029495  0.058639      0.44
# 14 16 days  84.869061  9.212441  5.851755  0.071810  0.034396  0.067278      0.40
# 15 17 days  87.539550  9.356257  6.055772  0.074890  0.048443  0.071136      0.40
# 16 18 days  79.895205  8.938412  5.970160  0.075001  0.052800  0.072389      0.40
# 17 19 days  51.897342  7.203981  4.602475  0.063101  0.043187  0.062128      0.34
# 18 20 days  16.681774  4.084333  2.930414  0.047589  0.040004  0.048331      0.44
# 19 21 days   8.693553  2.948483  2.319242  0.038962  0.031547  0.039970      0.70
# 20 22 days  56.295675  7.503044  3.957288  0.051754  0.029651  0.049740      0.76
# <ipython-input-20-a649196c1856>:12: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#                              modelo    MSE  MSE_std
# 0  Prophet_Treino_365_Horizon_22_m0  33.85     26.9

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv_m0, metric='mse')
# Out:
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:546: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:547: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.

# %% [markdown]
# ## Prophet | Treino 1 ano | Horizon 22 (m1)

# %%
df_cv_m1 = cross_validation(m1, period='365 days', horizon = '22 days')
df_p_m1 = performance_metrics(df_cv_m1)
print('MSE médio: ', df_p_m1.mse.mean())
print('MSE std: ', df_p_m1.mse.std())
print('MSE 22: ', df_p_m1.mse[20])

new_row = pd.DataFrame([{'modelo': 'Prophet_Treino_365_Horizon_22_m1',
                         'MSE': np.round(df_p_m1.mse.mean(), 2),
                         'MSE_std': np.round(df_p_m1.mse.std(), 2)}])

df_validacao = pd.concat([df_validacao, new_row], ignore_index=True)
display(df_validacao)

fig = plot_cross_validation_metric(df_cv_m1, metric='mse')
# Out:
# INFO:prophet:Making 7 forecasts with cutoffs between 2014-03-12 00:00:00 and 2020-03-10 00:00:00
#   0%|          | 0/7 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/ne5l_j2l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/8gb7spnc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78465', 'data', 'file=/tmp/tmp5d92cl46/ne5l_j2l.json', 'init=/tmp/tmp5d92cl46/8gb7spnc.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelalt7wggg/prophet_model-20241028231306.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/cflp46om.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/txqnzl1z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11495', 'data', 'file=/tmp/tmp5d92cl46/cflp46om.json', 'init=/tmp/tmp5d92cl46/txqnzl1z.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model5wuvx38i/prophet_model-20241028231307.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/ypwh4o1x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/rmg3dg1s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48080', 'data', 'file=/tmp/tmp5d92cl46/ypwh4o1x.json', 'init=/tmp/tmp5d92cl46/rmg3dg1s.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelggaf79f4/prophet_model-20241028231307.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/9agdtv0k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/bu8c82gt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74845', 'data', 'file=/tmp/tmp5d92cl46/9agdtv0k.json', 'init=/tmp/tmp5d92cl46/bu8c82gt.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelogoxpbfe/prophet_model-20241028231308.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/vgmdbp4c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/te4qk7wu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93446', 'data', 'file=/tmp/tmp5d92cl46/vgmdbp4c.json', 'init=/tmp/tmp5d92cl46/te4qk7wu.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modeln95mc6z4/prophet_model-20241028231309.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/8yfg40wm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/apwc4uzu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45022', 'data', 'file=/tmp/tmp5d92cl46/8yfg40wm.json', 'init=/tmp/tmp5d92cl46/apwc4uzu.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelwmalkz95/prophet_model-20241028231310.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/2lrymdiz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/bn07zq8z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6744', 'data', 'file=/tmp/tmp5d92cl46/2lrymdiz.json', 'init=/tmp/tmp5d92cl46/bn07zq8z.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelzzreu3xj/prophet_model-20241028231311.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# MSE médio:  45.75514640972764
# MSE std:  40.93641731027788
# MSE 22:  71.45985665411033
#                              modelo    MSE  MSE_std
# 0  Prophet_Treino_365_Horizon_22_m0  33.85    26.90
# 1  Prophet_Treino_365_Horizon_22_m1  45.76    40.94
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:546: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:547: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.

# %% [markdown]
# # Models comparison

# %%
import matplotlib.pyplot as plt

# Create a new figure and axis
fig, ax = plt.subplots(figsize = (20, 6))

# Plot the first DataFrame
df_p_m0['horizon'] = df_p_m0['horizon'].astype(str)
df_p_m0.set_index('horizon', inplace = True)
df_p_m0.plot(y='mse', ax=ax, label='Model 0', color='blue')

# Plot the second DataFrame
df_p_m1['horizon'] = df_p_m1['horizon'].astype(str)
df_p_m1.set_index('horizon', inplace = True)
df_p_m1.plot(y='mse', ax=ax, label='Model 1', color='green')

# Add titles and labels
ax.set_title('MSE vs Horizon for Model 0 and Model 1')
ax.set_xlabel('Horizon')
ax.set_ylabel('MSE')

# Show the legend
ax.legend()

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'horizon'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-8b68b1856534> in <cell line: 7>()
#       5
#       6 # Plot the first DataFrame
# ----> 7 df_p_m0['horizon'] = df_p_m0['horizon'].astype(str)
#       8 df_p_m0.set_index('horizon', inplace = True)
#       9 df_p_m0.plot(y='mse', ax=ax, label='Model 0', color='blue')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'horizon'

# %% [markdown]
# # Exercicio
# 1. Avaliar demais modelos m2 a m4,
# 2. Adicionar os resultados no df_validação
# 3. Plotar o plot_cross_validation_metric de cada modelo, de preferencia sobrepondo as curvas no mesmo grafico, diferenciando por cores.
# 4. Teste outros valores para "changepoint_prior_scale" e "changepoints"
# 5. Teste outros hyperparametros e adicione as metricas em df_validacao
# https://facebook.github.io/prophet/docs/seasonality,_holiday_effects,_and_regressors.html#fourier-order-for-seasonalities
#
# Exemplos:
# ###########################################################
#
# m = Prophet(yearly_seasonality=20).fit(df)
# ###########################################################
#
# m = Prophet(weekly_seasonality=False)
# m.add_seasonality(name='monthly', period=30.5, fourier_order=5)
# ###########################################################

# %% [markdown]
# #m5

# %%
m5 = Prophet(changepoints=['2019-08'],changepoint_prior_scale=0.33,yearly_seasonality=False,seasonality_mode="additive",growth="linear")
forecast = m5.fit(ts).predict(future)
fig = m5.plot(forecast)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/buu28up_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/ho809zp8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94397', 'data', 'file=/tmp/tmp5d92cl46/buu28up_.json', 'init=/tmp/tmp5d92cl46/ho809zp8.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model92ebvn55/prophet_model-20241028231313.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# #m6

# %%
m6 = Prophet(changepoints=['2019-08'],changepoint_prior_scale=0.5,yearly_seasonality=True,seasonality_mode="multiplicative",growth="linear")
forecast = m6.fit(ts).predict(future)
fig = m6.plot(forecast)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/fujj3f54.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/mr4wc9ck.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44431', 'data', 'file=/tmp/tmp5d92cl46/fujj3f54.json', 'init=/tmp/tmp5d92cl46/mr4wc9ck.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelyhiirui4/prophet_model-20241028231315.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# #m7

# %%
m7 = Prophet(changepoints=['2018-01'],changepoint_prior_scale=0.75,yearly_seasonality=True,seasonality_mode="additive",growth="linear")
forecast = m7.fit(ts).predict(future)
fig = m7.plot(forecast)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/wnvamtgb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/20v4051v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54931', 'data', 'file=/tmp/tmp5d92cl46/wnvamtgb.json', 'init=/tmp/tmp5d92cl46/20v4051v.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model6dzsf3gl/prophet_model-20241028231316.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
df_cv_m2 = cross_validation(m2, period='365 days', horizon = '22 days')
df_p_m2 = performance_metrics(df_cv_m2)
print('MSE médio: ', df_p_m2.mse.mean())
print('MSE std: ', df_p_m2.mse.std())
print('MSE 22: ', df_p_m2.mse[20])

new_row = pd.DataFrame([{'modelo': 'Prophet_Treino_365_Horizon_22_m1',
                         'MSE': np.round(df_p_m2.mse.mean(), 2),
                         'MSE_std': np.round(df_p_m2.mse.std(), 2)}])

df_validacao = pd.concat([df_validacao, new_row], ignore_index=True)
display(df_validacao)

fig = plot_cross_validation_metric(df_cv_m2, metric='mse')
# Out:
# INFO:prophet:Making 7 forecasts with cutoffs between 2014-03-12 00:00:00 and 2020-03-10 00:00:00
#   0%|          | 0/7 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/wxy845g5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/smsi7eiv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21067', 'data', 'file=/tmp/tmp5d92cl46/wxy845g5.json', 'init=/tmp/tmp5d92cl46/smsi7eiv.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model90_ti6wr/prophet_model-20241028231318.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/9ke7ndci.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/m25i7l2o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71934', 'data', 'file=/tmp/tmp5d92cl46/9ke7ndci.json', 'init=/tmp/tmp5d92cl46/m25i7l2o.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelnlsbfiru/prophet_model-20241028231318.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/_shpwspi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/fs80fjgh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91849', 'data', 'file=/tmp/tmp5d92cl46/_shpwspi.json', 'init=/tmp/tmp5d92cl46/fs80fjgh.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model3wwgwrma/prophet_model-20241028231319.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/sa2xpz8z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/wyom44nj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93661', 'data', 'file=/tmp/tmp5d92cl46/sa2xpz8z.json', 'init=/tmp/tmp5d92cl46/wyom44nj.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model8jkiultl/prophet_model-20241028231319.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/0tkeqd07.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/yuiuv1pc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74922', 'data', 'file=/tmp/tmp5d92cl46/0tkeqd07.json', 'init=/tmp/tmp5d92cl46/yuiuv1pc.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelxhl8gu4t/prophet_model-20241028231320.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/96ajb_4d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/tewwpery.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11403', 'data', 'file=/tmp/tmp5d92cl46/96ajb_4d.json', 'init=/tmp/tmp5d92cl46/tewwpery.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model_16s4c0e/prophet_model-20241028231322.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/8sew2amw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/tw4q1gl5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24980', 'data', 'file=/tmp/tmp5d92cl46/8sew2amw.json', 'init=/tmp/tmp5d92cl46/tw4q1gl5.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelelherkoj/prophet_model-20241028231324.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# MSE médio:  49.52567764538042
# MSE std:  43.81362032850782
# MSE 22:  75.48633403766634
#                              modelo    MSE  MSE_std
# 0  Prophet_Treino_365_Horizon_22_m0  33.85    26.90
# 1  Prophet_Treino_365_Horizon_22_m1  45.76    40.94
# 2  Prophet_Treino_365_Horizon_22_m1  49.53    43.81
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:546: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:547: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.

# %%
df_cv_m3 = cross_validation(m3, period='365 days', horizon = '22 days')
df_p_m3 = performance_metrics(df_cv_m3)
print('MSE médio: ', df_p_m3.mse.mean())
print('MSE std: ', df_p_m3.mse.std())
print('MSE 22: ', df_p_m3.mse[20])

new_row = pd.DataFrame([{'modelo': 'Prophet_Treino_365_Horizon_22_m1',
                         'MSE': np.round(df_p_m3.mse.mean(), 2),
                         'MSE_std': np.round(df_p_m3.mse.std(), 2)}])

df_validacao = pd.concat([df_validacao, new_row], ignore_index=True)
display(df_validacao)

fig = plot_cross_validation_metric(df_cv_m3, metric='mse')
# Out:
# INFO:prophet:Making 7 forecasts with cutoffs between 2014-03-12 00:00:00 and 2020-03-10 00:00:00
#   0%|          | 0/7 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/6ljddf31.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/5esci0jf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17421', 'data', 'file=/tmp/tmp5d92cl46/6ljddf31.json', 'init=/tmp/tmp5d92cl46/5esci0jf.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model5mvl5bni/prophet_model-20241028231325.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/dz_4dnaz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/nc5spk5g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48684', 'data', 'file=/tmp/tmp5d92cl46/dz_4dnaz.json', 'init=/tmp/tmp5d92cl46/nc5spk5g.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelangsn6fq/prophet_model-20241028231326.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 23:13:26 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/mdzhxyij.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/togy8bpm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7299', 'data', 'file=/tmp/tmp5d92cl46/mdzhxyij.json', 'init=/tmp/tmp5d92cl46/togy8bpm.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelaw1_qu8g/prophet_model-20241028231326.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:13:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/flxu0g0f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/q9gf7gjk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21210', 'data', 'file=/tmp/tmp5d92cl46/flxu0g0f.json', 'init=/tmp/tmp5d92cl46/q9gf7gjk.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelstzscsrd/prophet_model-20241028231329.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/piy4b_lu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/yexyl4n4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7439', 'data', 'file=/tmp/tmp5d92cl46/piy4b_lu.json', 'init=/tmp/tmp5d92cl46/yexyl4n4.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelcqlwriul/prophet_model-20241028231329.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/ejf89o9d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/p9wblq4_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11416', 'data', 'file=/tmp/tmp5d92cl46/ejf89o9d.json', 'init=/tmp/tmp5d92cl46/p9wblq4_.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelog59335_/prophet_model-20241028231330.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/w_fwmo19.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/9y3yrd27.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26451', 'data', 'file=/tmp/tmp5d92cl46/w_fwmo19.json', 'init=/tmp/tmp5d92cl46/9y3yrd27.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model63nax0i6/prophet_model-20241028231330.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 23:13:30 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/hmldtq6q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/_ukvvubq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6860', 'data', 'file=/tmp/tmp5d92cl46/hmldtq6q.json', 'init=/tmp/tmp5d92cl46/_ukvvubq.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model4023i4qu/prophet_model-20241028231330.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:13:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/1rr7yjeg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/d_7yvn24.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2426', 'data', 'file=/tmp/tmp5d92cl46/1rr7yjeg.json', 'init=/tmp/tmp5d92cl46/d_7yvn24.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modellcm4bhdv/prophet_model-20241028231331.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# MSE médio:  168.25572986773543
# MSE std:  101.88506953884902
# MSE 22:  70.48590599524509
#                              modelo     MSE  MSE_std
# 0  Prophet_Treino_365_Horizon_22_m0   33.85    26.90
# 1  Prophet_Treino_365_Horizon_22_m1   45.76    40.94
# 2  Prophet_Treino_365_Horizon_22_m1   49.53    43.81
# 3  Prophet_Treino_365_Horizon_22_m1  168.26   101.89
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:546: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:547: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.

# %%
df_cv_m4 = cross_validation(m4, period='365 days', horizon = '22 days')
df_p_m4 = performance_metrics(df_cv_m4)
print('MSE médio: ', df_p_m4.mse.mean())
print('MSE std: ', df_p_m4.mse.std())
print('MSE 22: ', df_p_m4.mse[20])

new_row = pd.DataFrame([{'modelo': 'Prophet_Treino_365_Horizon_22_m1',
                         'MSE': np.round(df_p_m4.mse.mean(), 2),
                         'MSE_std': np.round(df_p_m4.mse.std(), 2)}])

df_validacao = pd.concat([df_validacao, new_row], ignore_index=True)
display(df_validacao)

fig = plot_cross_validation_metric(df_cv_m4, metric='mse')
# Out:
# INFO:prophet:Making 7 forecasts with cutoffs between 2014-03-12 00:00:00 and 2020-03-10 00:00:00
#   0%|          | 0/7 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/trhgjtjy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/fxtj1huv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95191', 'data', 'file=/tmp/tmp5d92cl46/trhgjtjy.json', 'init=/tmp/tmp5d92cl46/fxtj1huv.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model34l0dlt5/prophet_model-20241028231332.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/irxnppg5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/r9ltiu99.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9960', 'data', 'file=/tmp/tmp5d92cl46/irxnppg5.json', 'init=/tmp/tmp5d92cl46/r9ltiu99.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modeliool93cn/prophet_model-20241028231332.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 23:13:32 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/lp0n0vt3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/o6sm4s15.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99415', 'data', 'file=/tmp/tmp5d92cl46/lp0n0vt3.json', 'init=/tmp/tmp5d92cl46/o6sm4s15.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelhqg9ejxj/prophet_model-20241028231332.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:13:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/3c5rbwjl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/o3l_vh7f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88520', 'data', 'file=/tmp/tmp5d92cl46/3c5rbwjl.json', 'init=/tmp/tmp5d92cl46/o3l_vh7f.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelq3ei94v5/prophet_model-20241028231334.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/26c3_18t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/ruci2yu0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5614', 'data', 'file=/tmp/tmp5d92cl46/26c3_18t.json', 'init=/tmp/tmp5d92cl46/ruci2yu0.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelgvtvwr3t/prophet_model-20241028231335.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/wvkbuzwz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/kvuy_onq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54559', 'data', 'file=/tmp/tmp5d92cl46/wvkbuzwz.json', 'init=/tmp/tmp5d92cl46/kvuy_onq.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelr17yc5ih/prophet_model-20241028231335.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/cwhvv_k6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/gwegfr3v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25983', 'data', 'file=/tmp/tmp5d92cl46/cwhvv_k6.json', 'init=/tmp/tmp5d92cl46/gwegfr3v.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelcz97tzx4/prophet_model-20241028231335.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 23:13:35 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/_5n5gfs8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/lb4qi2ug.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94084', 'data', 'file=/tmp/tmp5d92cl46/_5n5gfs8.json', 'init=/tmp/tmp5d92cl46/lb4qi2ug.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelkz082qjp/prophet_model-20241028231335.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:13:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/3klk2vqr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/sov9m7r1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1615', 'data', 'file=/tmp/tmp5d92cl46/3klk2vqr.json', 'init=/tmp/tmp5d92cl46/sov9m7r1.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model4et60c2h/prophet_model-20241028231336.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# MSE médio:  129.94586126084917
# MSE std:  90.72227988391158
# MSE 22:  208.4262668285262
#                              modelo     MSE  MSE_std
# 0  Prophet_Treino_365_Horizon_22_m0   33.85    26.90
# 1  Prophet_Treino_365_Horizon_22_m1   45.76    40.94
# 2  Prophet_Treino_365_Horizon_22_m1   49.53    43.81
# 3  Prophet_Treino_365_Horizon_22_m1  168.26   101.89
# 4  Prophet_Treino_365_Horizon_22_m1  129.95    90.72
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:546: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:547: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.

# %%
df_cv_m5 = cross_validation(m5, period='365 days', horizon = '22 days')
df_p_m5 = performance_metrics(df_cv_m5)
print('MSE médio: ', df_p_m5.mse.mean())
print('MSE std: ', df_p_m5.mse.std())
print('MSE 22: ', df_p_m5.mse[20])

new_row = pd.DataFrame([{'modelo': 'Prophet_Treino_365_Horizon_22_m1',
                         'MSE': np.round(df_p_m5.mse.mean(), 2),
                         'MSE_std': np.round(df_p_m5.mse.std(), 2)}])

df_validacao = pd.concat([df_validacao, new_row], ignore_index=True)
display(df_validacao)

fig = plot_cross_validation_metric(df_cv_m5, metric='mse')
# Out:
# INFO:prophet:Making 8 forecasts with cutoffs between 2013-03-12 00:00:00 and 2020-03-10 00:00:00
#   0%|          | 0/8 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/t4585tsj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/yo1fm5b9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90135', 'data', 'file=/tmp/tmp5d92cl46/t4585tsj.json', 'init=/tmp/tmp5d92cl46/yo1fm5b9.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modeltay2fgz6/prophet_model-20241028231337.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:13:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/tvehrhut.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/zqubip6n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22031', 'data', 'file=/tmp/tmp5d92cl46/tvehrhut.json', 'init=/tmp/tmp5d92cl46/zqubip6n.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model5rbl_tee/prophet_model-20241028231337.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 23:13:37 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/667bhcsa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/faywzdeh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed
series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:547: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.

# %%
df_cv_m6 = cross_validation(m6, period='365 days', horizon = '22 days')
df_p_m6 = performance_metrics(df_cv_m6)
print('MSE médio: ', df_p_m6.mse.mean())
print('MSE std: ', df_p_m6.mse.std())
print('MSE 22: ', df_p_m6.mse[20])

new_row = pd.DataFrame([{'modelo': 'Prophet_Treino_365_Horizon_22_m1',
                         'MSE': np.round(df_p_m6.mse.mean(), 2),
                         'MSE_std': np.round(df_p_m6.mse.std(), 2)}])

df_validacao = pd.concat([df_validacao, new_row], ignore_index=True)
display(df_validacao)

fig = plot_cross_validation_metric(df_cv_m6, metric='mse')
# Out:
# INFO:prophet:Making 7 forecasts with cutoffs between 2014-03-12 00:00:00 and 2020-03-10 00:00:00
#   0%|          | 0/7 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/gvbrxf_0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/p1xwqs78.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75553', 'data', 'file=/tmp/tmp5d92cl46/gvbrxf_0.json', 'init=/tmp/tmp5d92cl46/p1xwqs78.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model3fmrfqkb/prophet_model-20241028231340.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/cmf5itte.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/8vbja1hs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81640', 'data', 'file=/tmp/tmp5d92cl46/cmf5itte.json', 'init=/tmp/tmp5d92cl46/8vbja1hs.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model2_kyu0es/prophet_model-20241028231340.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/9a_wh2wd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/xlveaslt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79836', 'data', 'file=/tmp/tmp5d92cl46/9a_wh2wd.json', 'init=/tmp/tmp5d92cl46/xlveaslt.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelb51bvhzt/prophet_model-20241028231340.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/qcmzyr7b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/b6vgiwj4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51737', 'data', 'file=/tmp/tmp5d92cl46/qcmzyr7b.json', 'init=/tmp/tmp5d92cl46/b6vgiwj4.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model007q1ejz/prophet_model-20241028231341.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/qlnwk6dp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/sjbq80jg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99906', 'data', 'file=/tmp/tmp5d92cl46/qlnwk6dp.json', 'init=/tmp/tmp5d92cl46/sjbq80jg.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelrtvce145/prophet_model-20241028231341.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/h6vomboe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/gamhb5la.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62055', 'data', 'file=/tmp/tmp5d92cl46/h6vomboe.json', 'init=/tmp/tmp5d92cl46/gamhb5la.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model74p6ttyu/prophet_model-20241028231342.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/uid0j3oo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/fvsrulqv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28028', 'data', 'file=/tmp/tmp5d92cl46/uid0j3oo.json', 'init=/tmp/tmp5d92cl46/fvsrulqv.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelmq3fmrhi/prophet_model-20241028231342.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# MSE médio:  167.66161975574215
# MSE std:  109.46488456537763
# MSE 22:  60.176322562737894
#                              modelo     MSE  MSE_std
# 0  Prophet_Treino_365_Horizon_22_m0   33.85    26.90
# 1  Prophet_Treino_365_Horizon_22_m1   45.76    40.94
# 2  Prophet_Treino_365_Horizon_22_m1   49.53    43.81
# 3  Prophet_Treino_365_Horizon_22_m1  168.26   101.89
# 4  Prophet_Treino_365_Horizon_22_m1  129.95    90.72
# 5  Prophet_Treino_365_Horizon_22_m1  132.75    75.69
# 6  Prophet_Treino_365_Horizon_22_m1  167.66   109.46
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:546: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:547: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.

# %%
df_cv_m7 = cross_validation(m7, period='365 days', horizon = '22 days')
df_p_m7 = performance_metrics(df_cv_m7)
print('MSE médio: ', df_p_m7.mse.mean())
print('MSE std: ', df_p_m7.mse.std())
print('MSE 22: ', df_p_m7.mse[20])

new_row = pd.DataFrame([{'modelo': 'Prophet_Treino_365_Horizon_22_m1',
                         'MSE': np.round(df_p_m7.mse.mean(), 2),
                         'MSE_std': np.round(df_p_m7.mse.std(), 2)}])

df_validacao = pd.concat([df_validacao, new_row], ignore_index=True)
display(df_validacao)

fig = plot_cross_validation_metric(df_cv_m7, metric='mse')
# Out:
# INFO:prophet:Making 7 forecasts with cutoffs between 2014-03-12 00:00:00 and 2020-03-10 00:00:00
#   0%|          | 0/7 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/ka1dkius.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/0c5pm0hj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23901', 'data', 'file=/tmp/tmp5d92cl46/ka1dkius.json', 'init=/tmp/tmp5d92cl46/0c5pm0hj.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelhhatzxrl/prophet_model-20241028231343.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/dr4zcs41.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/ayjcgg7k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56024', 'data', 'file=/tmp/tmp5d92cl46/dr4zcs41.json', 'init=/tmp/tmp5d92cl46/ayjcgg7k.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelbgcm58np/prophet_model-20241028231344.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/m33qaz_o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/mxspzv3g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72270', 'data', 'file=/tmp/tmp5d92cl46/m33qaz_o.json', 'init=/tmp/tmp5d92cl46/mxspzv3g.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_modelr02hp1cj/prophet_model-20241028231344.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/l_2v9j6f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/r2mb96p0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46682', 'data', 'file=/tmp/tmp5d92cl46/l_2v9j6f.json', 'init=/tmp/tmp5d92cl46/r2mb96p0.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model04q_79m8/prophet_model-20241028231344.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/dkc_7w9x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/m56r0jls.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63349', 'data', 'file=/tmp/tmp5d92cl46/dkc_7w9x.json', 'init=/tmp/tmp5d92cl46/m56r0jls.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model50e71a9_/prophet_model-20241028231344.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/u34xhhbf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/2u9hnx5k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62201', 'data', 'file=/tmp/tmp5d92cl46/u34xhhbf.json', 'init=/tmp/tmp5d92cl46/2u9hnx5k.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model3lhlzvje/prophet_model-20241028231345.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/debfcub6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5d92cl46/wk1d_p9x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3561', 'data', 'file=/tmp/tmp5d92cl46/debfcub6.json', 'init=/tmp/tmp5d92cl46/wk1d_p9x.json', 'output', 'file=/tmp/tmp5d92cl46/prophet_model52mj8bzb/prophet_model-20241028231345.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# MSE médio:  276.20231628098156
# MSE std:  207.84997513019076
# MSE 22:  428.2726634681644
#                              modelo     MSE  MSE_std
# 0  Prophet_Treino_365_Horizon_22_m0   33.85    26.90
# 1  Prophet_Treino_365_Horizon_22_m1   45.76    40.94
# 2  Prophet_Treino_365_Horizon_22_m1   49.53    43.81
# 3  Prophet_Treino_365_Horizon_22_m1  168.26   101.89
# 4  Prophet_Treino_365_Horizon_22_m1  129.95    90.72
# 5  Prophet_Treino_365_Horizon_22_m1  132.75    75.69
# 6  Prophet_Treino_365_Horizon_22_m1  167.66   109.46
# 7  Prophet_Treino_365_Horizon_22_m1  276.20   207.85
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:546: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:547: FutureWarning:
#
# Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.

# %% [markdown]
# # Nova secção

# %%
import matplotlib.pyplot as plt

# Create a new figure and axis
fig, ax = plt.subplots(figsize = (20, 6))

df_p_m0['horizon'] = df_p_m0['horizon'].astype(str)
df_p_m0.set_index('horizon', inplace = True)
df_p_m0.plot(y='mse', ax=ax, label='Model 0', color='blue')

df_p_m1['horizon'] = df_p_m1['horizon'].astype(str)
df_p_m1.set_index('horizon', inplace = True)
df_p_m1.plot(y='mse', ax=ax, label='Model 1', color='green')

df_p_m2['horizon'] = df_p_m2['horizon'].astype(str)
df_p_m2.set_index('horizon', inplace = True)
df_p_m2.plot(y='mse', ax=ax, label='Model 2', color='red')

df_p_m3['horizon'] = df_p_m3['horizon'].astype(str)
df_p_m3.set_index('horizon', inplace = True)
df_p_m3.plot(y='mse', ax=ax, label='Model 3', color='orange')

df_p_m4['horizon'] = df_p_m4['horizon'].astype(str)
df_p_m4.set_index('horizon', inplace = True)
df_p_m4.plot(y='mse', ax=ax, label='Model 4', color='purple')

df_p_m5['horizon'] = df_p_m5['horizon'].astype(str)
df_p_m5.set_index('horizon', inplace = True)
df_p_m5.plot(y='mse', ax=ax, label='Model 5', color='pink')

df_p_m6['horizon'] = df_p_m6['horizon'].astype(str)
df_p_m6.set_index('horizon', inplace = True)
df_p_m6.plot(y='mse', ax=ax, label='Model 6', color='yellow')

df_p_m7['horizon'] = df_p_m7['horizon'].astype(str)
df_p_m7.set_index('horizon', inplace = True)
df_p_m7.plot(y='mse', ax=ax, label='Model 7', color='Brown')

# Add titles and labels
ax.set_title('MSE vs Horizon todos os modelos')
ax.set_xlabel('Horizon')
ax.set_ylabel('MSE')

# Show the legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# com base analisando este grafico o melhor modelo aparentemente é o modelo 0 que não tem nenhum paremetro setado esta com tudo default por conta do baixo mse e por ele ter se mantido assim desde o inicio e o modelo que eu melhor montei os parametros seria o 6 e o 3 por conta apesar de eles terem começado com um mse baixo eles foram abaixando com forme o passar do tempo
